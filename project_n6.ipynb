# %% [markdown]
# # Самостоятельный проект. Обучение с учителем: качество модели

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
#
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
#
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.
#
# Как решать задачу
#
# Продумывать подход к решению этой задачи вам не придётся — руководитель отдела его уже сформировал:
#
# Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
#
# Нужно собрать данные по клиентам по следующим группам:
# - Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# - Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# - Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# - Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# Представим группы признаков (вместе с целевым) в виде диаграммы — такую визуализацию ещё называют диаграммой Исикавы.
#
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 2. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 3. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# Руководство одобрило описание решения, и вам, как специалисту по DS, нужно его реализовать.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные для работы находятся в нескольких таблицах. Нажмите на название файла, чтобы его скачать.
#
# 1. market_file.csv
# - Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и
# прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
# 2. market_money.csv
# - Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксирована выручка. Например,
# 'текущий_месяц' или 'предыдущий_месяц'.
# - Выручка — сумма выручки за период.
#
# 3. market_time.csv
# - Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
# - id — номер покупателя в корпоративной базе данных.
# - Период — название периода, во время которого зафиксировано общее время.
# - минут — значение времени, проведённого на сайте, в минутах.
#
# 4. money.csv
# - Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
# - id — номер покупателя в корпоративной базе данных.
# - Прибыль — значение прибыли.

# %% [markdown]
# ### Инструкция по выполнению проекта

# %% [markdown]
# Решать задачу вам нужно в два этапа:
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов, но вы также можете выделить свой:
#
# - Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# - Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# - Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# - Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
# !pip install matplotlib==3.8.3 -q

# %%
# !pip install seaborn==0.13.2 -q

# %%
# !pip install scikit-learn==1.6 -q

# %%
# !pip install phik -q

# %%
# !pip install shap -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import phik
from pprint import pprint
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import roc_auc_score

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# 1.1 Загрузите данные. Файлы market_file.csv, market_money.csv, market_time.csv, money.csv доступны по ссылкам в описании данных или через пути к ним:
#
# - /datasets/market_file.csv
# - /datasets/market_money.csv
# - /datasets/market_time.csv
# - /datasets/money.csv
#
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.
#
# 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.

# %%
try:
    market_file = pd.read_csv('market_file.csv', sep=',')
    market_money = pd.read_csv('market_money.csv', sep=',')
    market_time = pd.read_csv('market_time.csv', sep=',')
    money = pd.read_csv('money.csv', sep=';', decimal=',')
except:
    market_file = pd.read_csv('/datasets/market_file.csv', sep=',')
    market_money = pd.read_csv('/datasets/market_money.csv', sep=',')
    market_time = pd.read_csv('/datasets/market_time.csv', sep=',')
    money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# %%
dfs = [market_file, market_money, market_time, money]

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  11  Ошибка_сервиса                       1300 non-null   int64
#  12  Страниц_за_визит                     1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 132.2+ KB

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
for df in dfs:
    print(df.head(5))
    print('\n')
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    6
# 1     Товары для детей                                    4
# 2    Домашний текстиль                                    5
# 3     Товары для детей                                    5
# 4     Товары для детей                                    3
#
#    Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# 0                                   2               1                 5
# 1                                   4               2                 5
# 2                                   2               1                 5
# 3                                   0               6                 4
# 4                                   2               3                 2
#
#
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
#
#
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
#
#
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# ### Промежуточный вывод
# В ходе осмотра данных выявлено:
# - названия столбцов на кириллице оставим, но приведем к нижнему змеиному регистру

# %% [markdown]
# ## Шаг 2. Предобработка данных
# Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.

# %% [markdown]
# ### Проведем устранение проблем, найденных на этапе загрузки

# %%
for df in dfs:
    df.columns = df.columns.str.replace(' ','_')
    df.columns = df.columns.str.casefold()

# %% [markdown]
# ### Проверка на дубликаты, пропуски данных

# %%
for n, df in enumerate(dfs):
    print(f'Файл №{n+1}')
    print('Дубликатов', df.duplicated().sum())
    print('Максимум пропусков', df.isna().sum().max())
    print('\n')
# Out:
# Файл №1
# Дубликатов 0
# Максимум пропусков 0
#
#
# Файл №2
# Дубликатов 0
# Максимум пропусков 0
#
#
# Файл №3
# Дубликатов 0
# Максимум пропусков 0
#
#
# Файл №4
# Дубликатов 0
# Максимум пропусков 0

# %% [markdown]
# Дубликаты, как и пропуски в данных отсутствуют. Выявим неявные дубликаты и исправим

# %%
for col in market_file.select_dtypes('object').columns:
    print(market_file[col].value_counts())
    print('\n')
# Out:
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
#
#
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
#
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
#
#
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %%
market_file['тип_сервиса'] = market_file['тип_сервиса'].str.replace('стандартт','стандарт')

# %%
market_file['тип_сервиса'].value_counts()
# Out:
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64

# %%
for col in market_money.select_dtypes('object').columns:
    print(market_money[col].value_counts())
    print('\n')
# Out:
# препредыдущий_месяц    1300
# текущий_месяц          1300
# предыдущий_месяц       1300
# Name: период, dtype: int64

# %%
for col in market_time.select_dtypes('object').columns:
    print(market_time[col].value_counts())
    print('\n')
# Out:
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: период, dtype: int64

# %%
market_time['период'] = market_time['период'].str.replace('предыдцщий_месяц','предыдущий_месяц')

# %%
market_time['период'].value_counts()
# Out:
# текущий_месяц       1300
# предыдущий_месяц    1300
# Name: период, dtype: int64

# %% [markdown]
# Опечатки в данных выявлены и исправлены

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных
# Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.

# %% [markdown]
# ### Построим гистограммы

# %%
def df_hist_num(df, bins=20, id=1):
    for col in df.select_dtypes('number').columns[id:]:
        df[col].hist(bins=bins)
        plt.title(f'Гистограмма по столбцу "{col}"')
        plt.show()

# %%
df_hist_num(market_file)

# %%
df_hist_num(market_money)

# %%
df_hist_num(market_time)

# %%
df_hist_num(money)

# %%
market_money.loc[market_money['выручка']>20000, 'выручка'] = market_money.loc[market_money['выручка']<20000, 'выручка'].mean()

# %%
market_money['выручка'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# #### Вывод по гистограммам
#
# Найдена аномалия в столбце выручка, в ходе исправления была произведена замена значения на среднее.
# По всем столбцам, кроме "акционные покупки" наблюдается либо нормальное распределение, либо распределение Пуассона

# %% [markdown]
# ### Отберем в датасете пользователей с покупательной активностью не менее 3 месяцев

# %%
market_money['период'].value_counts()
# Out:
# препредыдущий_месяц    1300
# текущий_месяц          1300
# предыдущий_месяц       1300
# Name: период, dtype: int64

# %%
noactiv_id = market_money.loc[market_money['выручка']==0,'id'].unique().tolist()
noactiv_id
# Out:
# [215348, 215357, 215359]

# %%
market_file = market_file[~market_file['id'].isin(noactiv_id)]
print(market_file.shape[0])

market_time = market_time[~market_time['id'].isin(noactiv_id)]
print(market_time.shape[0])

market_money = market_money[~market_money['id'].isin(noactiv_id)]
print(market_money.shape[0])

money = money[~money['id'].isin(noactiv_id)]
print(money.shape[0])
# Out:
# 1297
# 2594
# 3891
# 1297

# %% [markdown]
# #### Промежуточный вывод отбора
#
# В результате датасеты обновлены с учетом наличия в них только пользователей с платежеспособной активностью не менее 3-х месяцев

# %% [markdown]
# ## Шаг 4. Объединение таблиц
# 4.1 Объедините таблицы market_file.csv, market_money.csv, market_time.csv. Данные о прибыли из файла money.csv при моделировании вам не понадобятся.
#
# 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.

# %%
for df in dfs:
    print(df.columns)
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')
# Index(['id', 'период', 'выручка'], dtype='object')
# Index(['id', 'период', 'минут'], dtype='object')
# Index(['id', 'прибыль'], dtype='object')

# %%
market_file[market_file['id']==215349]
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 1  215349                 Снизилась     премиум                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 1                 4.4                     4           819               0.75
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 1     Товары для детей                                    4
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# 1                                   4               2                 5

# %%
market_money[market_money['id']==215349]
# Out:
#        id               период  выручка
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# 5  215349     предыдущий_месяц   5216.0

# %%
market_time[market_time['id']==215349]
# Out:
#        id            период  минут
# 2  215349     текущий_месяц     10
# 3  215349  предыдущий_месяц     12

# %%
def re_col(df, label):
    for period in df['период'].unique():
        df.loc[df['период'] == period, f'{label}_{period}'] = df.loc[df['период'] == period, label]
    df = df.drop(columns=['период',label])
    # df = df.fillna(0)
    df = df.groupby('id', as_index=False).sum()
    return df

# %%
re_col(market_money, 'выручка')
# Out:
# c:\Users\navoh\.conda\envs\practicum\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# c:\Users\navoh\.conda\envs\practicum\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#           id  выручка_препредыдущий_месяц  выручка_текущий_месяц  \
# 0     215349                       4472.0                 4971.6
# 1     215350                       4826.0                 5058.4
# 2     215351                       4793.0                 6610.4
# 3     215352                       4594.0                 5872.5
# 4     215353                       5124.0                 5388.5
# ...      ...                          ...                    ...
# 1292  216643                       4704.0                 4741.7
# 1293  216644                       5299.0                 5353.0
# 1294  216645                       5334.0                 5139.2
# 1295  216646                       4725.0                 5224.6
# 1296  216647                       5183.0                 4448.3
#
#       выручка_предыдущий_месяц
# 0                       5216.0
# 1                       5457.5
# 2                       6158.0
# 3                       5807.5
# 4                       4738.5
# ...                        ...
# 1292                    3664.0
# 1293                    4729.0
# 1294                    5160.0
# 1295                    4923.0
# 1296                    4720.0
#
# [1297 rows x 4 columns]

# %%
market = pd.merge(market_file, re_col(market_time, 'минут'), on='id')
market = pd.merge(market, re_col(market_money, 'выручка'), on='id')
market.info()
# Out:
# c:\Users\navoh\.conda\envs\practicum\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# c:\Users\navoh\.conda\envs\practicum\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1297 entries, 0 to 1296
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1297 non-null   int64
#  1   покупательская_активность            1297 non-null   object
#  2   тип_сервиса                          1297 non-null   object
#  3   разрешить_сообщать                   1297 non-null   object
#  4   маркет_актив_6_мес                   1297 non-null   float64
#  5   маркет_актив_тек_мес                 1297 non-null   int64
#  6   длительность                         1297 non-null   int64
#  7   акционные_покупки                    1297 non-null   float64
#  8   популярная_категория                 1297 non-null   object
#  9   средний_просмотр_категорий_за_визит  1297 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1297 non-null   int64
#  11  ошибка_сервиса                       1297 non-null   int64
#  12  страниц_за_визит                     1297 non-null   int64
#  13  минут_текущий_месяц                  1297 non-null   float64
#  14  минут_предыдущий_месяц               1297 non-null   float64
#  15  выручка_препредыдущий_месяц          1297 non-null   float64
#  16  выручка_текущий_месяц                1297 non-null   float64
#  17  выручка_предыдущий_месяц             1297 non-null   float64
# dtypes: float64(7), int64(7), object(4)
# memory usage: 192.5+ KB

# %% [markdown]
# ### Промежуточные результаты
#
# Данные объединены в датафрейм market

# %% [markdown]
# ## Шаг 5. Корреляционный анализ
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.

# %%
market.corr()
# Out:
#                                            id  маркет_актив_6_мес  \
# id                                   1.000000            0.355921
# маркет_актив_6_мес                   0.355921            1.000000
# маркет_актив_тек_мес                -0.006203            0.058556
# длительность                        -0.060385           -0.039157
# акционные_покупки                   -0.326324           -0.242752
# средний_просмотр_категорий_за_визит  0.271406            0.203090
# неоплаченные_продукты_штук_квартал  -0.293157           -0.164073
# ошибка_сервиса                       0.085214            0.034421
# страниц_за_визит                     0.499057            0.314881
# минут_текущий_месяц                  0.418908            0.221858
# минут_предыдущий_месяц               0.480114            0.288170
# выручка_препредыдущий_месяц          0.347172            0.241783
# выручка_текущий_месяц               -0.086268            0.013625
# выручка_предыдущий_месяц            -0.055704            0.016442
#
#                                      маркет_актив_тек_мес  длительность  \
# id                                              -0.006203     -0.060385
# маркет_актив_6_мес                               0.058556     -0.039157
# маркет_актив_тек_мес                             1.000000     -0.134009
# длительность                                    -0.134009      1.000000
# акционные_покупки                               -0.005580      0.012158
# средний_просмотр_категорий_за_визит             -0.023904     -0.054612
# неоплаченные_продукты_штук_квартал               0.054997     -0.092609
# ошибка_сервиса                                   0.087952      0.112254
# страниц_за_визит                                 0.005229     -0.039542
# минут_текущий_месяц                             -0.066598      0.092506
# минут_предыдущий_месяц                           0.011086     -0.122151
# выручка_препредыдущий_месяц                     -0.042649     -0.050222
# выручка_текущий_месяц                           -0.016671      0.015985
# выручка_предыдущий_месяц                        -0.033834      0.010120
#
#                                      акционные_покупки  \
# id                                           -0.326324
# маркет_актив_6_мес                           -0.242752
# маркет_актив_тек_мес                         -0.005580
# длительность                                  0.012158
# акционные_покупки                             1.000000
# средний_просмотр_категорий_за_визит          -0.170592
# неоплаченные_продукты_штук_квартал            0.190992
# ошибка_сервиса                               -0.024746
# страниц_за_визит                             -0.307003
# минут_текущий_месяц                          -0.217316
# минут_предыдущий_месяц                       -0.271253
# выручка_препредыдущий_месяц                  -0.200848
# выручка_текущий_месяц                         0.014300
# выручка_предыдущий_месяц                     -0.001828
#
#                                      средний_просмотр_категорий_за_визит  \
# id                                                              0.271406
# маркет_актив_6_мес                                              0.203090
# маркет_актив_тек_мес                                           -0.023904
# длительность                                                   -0.054612
# акционные_покупки                                              -0.170592
# средний_просмотр_категорий_за_визит                             1.000000
# неоплаченные_продукты_штук_квартал                             -0.274460
# ошибка_сервиса                                                  0.007024
# страниц_за_визит                                                0.240079
# минут_текущий_месяц                                             0.225631
# минут_предыдущий_месяц                                          0.135454
# выручка_препредыдущий_месяц                                     0.140738
# выручка_текущий_месяц                                          -0.074071
# выручка_предыдущий_месяц                                       -0.039673
#
#                                      неоплаченные_продукты_штук_квартал  \
# id                                                            -0.293157
# маркет_актив_6_мес                                            -0.164073
# маркет_актив_тек_мес                                           0.054997
# длительность                                                  -0.092609
# акционные_покупки                                              0.190992
# средний_просмотр_категорий_за_визит                           -0.274460
# неоплаченные_продукты_штук_квартал                             1.000000
# ошибка_сервиса                                                -0.092196
# страниц_за_визит                                              -0.194615
# минут_текущий_месяц                                           -0.206926
# минут_предыдущий_месяц                                        -0.182694
# выручка_препредыдущий_месяц                                   -0.262823
# выручка_текущий_месяц                                          0.038322
# выручка_предыдущий_месяц                                      -0.005893
#
#                                      ошибка_сервиса  страниц_за_визит  \
# id                                         0.085214          0.499057
# маркет_актив_6_мес                         0.034421          0.314881
# маркет_актив_тек_мес                       0.087952          0.005229
# длительность                               0.112254         -0.039542
# акционные_покупки                         -0.024746         -0.307003
# средний_просмотр_категорий_за_визит        0.007024          0.240079
# неоплаченные_продукты_штук_квартал        -0.092196         -0.194615
# ошибка_сервиса                             1.000000          0.087651
# страниц_за_визит                           0.087651          1.000000
# минут_текущий_месяц                        0.074364          0.254452
# минут_предыдущий_месяц                     0.187261          0.425325
# выручка_препредыдущий_месяц                0.076182          0.292719
# выручка_текущий_месяц                      0.031715         -0.029190
# выручка_предыдущий_месяц                   0.039707         -0.040131
#
#                                      минут_текущий_месяц  \
# id                                              0.418908
# маркет_актив_6_мес                              0.221858
# маркет_актив_тек_мес                           -0.066598
# длительность                                    0.092506
# акционные_покупки                              -0.217316
# средний_просмотр_категорий_за_визит             0.225631
# неоплаченные_продукты_штук_квартал             -0.206926
# ошибка_сервиса                                  0.074364
# страниц_за_визит                                0.254452
# минут_текущий_месяц                             1.000000
# минут_предыдущий_месяц                          0.349399
# выручка_препредыдущий_месяц                     0.299687
# выручка_текущий_месяц                          -0.162049
# выручка_предыдущий_месяц                       -0.052204
#
#                                      минут_предыдущий_месяц  \
# id                                                 0.480114
# маркет_актив_6_мес                                 0.288170
# маркет_актив_тек_мес                               0.011086
# длительность                                      -0.122151
# акционные_покупки                                 -0.271253
# средний_просмотр_категорий_за_визит                0.135454
# неоплаченные_продукты_штук_квартал                -0.182694
# ошибка_сервиса                                     0.187261
# страниц_за_визит                                   0.425325
# минут_текущий_месяц                                0.349399
# минут_предыдущий_месяц                             1.000000
# выручка_препредыдущий_месяц                        0.347279
# выручка_текущий_месяц                             -0.139007
# выручка_предыдущий_месяц                          -0.065080
#
#                                      выручка_препредыдущий_месяц  \
# id                                                      0.347172
# маркет_актив_6_мес                                      0.241783
# маркет_актив_тек_мес                                   -0.042649
# длительность                                           -0.050222
# акционные_покупки                                      -0.200848
# средний_просмотр_категорий_за_визит                     0.140738
# неоплаченные_продукты_штук_квартал                     -0.262823
# ошибка_сервиса                                          0.076182
# страниц_за_визит                                        0.292719
# минут_текущий_месяц                                     0.299687
# минут_предыдущий_месяц                                  0.347279
# выручка_препредыдущий_месяц                             1.000000
# выручка_текущий_месяц                                   0.121513
# выручка_предыдущий_месяц                                0.328247
#
#                                      выручка_текущий_месяц  \
# id                                               -0.086268
# маркет_актив_6_мес                                0.013625
# маркет_актив_тек_мес                             -0.016671
# длительность                                      0.015985
# акционные_покупки                                 0.014300
# средний_просмотр_категорий_за_визит              -0.074071
# неоплаченные_продукты_штук_квартал                0.038322
# ошибка_сервиса                                    0.031715
# страниц_за_визит                                 -0.029190
# минут_текущий_месяц                              -0.162049
# минут_предыдущий_месяц                           -0.139007
# выручка_препредыдущий_месяц                       0.121513
# выручка_текущий_месяц                             1.000000
# выручка_предыдущий_месяц                          0.837886
#
#                                      выручка_предыдущий_месяц
# id                                                  -0.055704
# маркет_актив_6_мес                                   0.016442
# маркет_актив_тек_мес                                -0.033834
# длительность                                         0.010120
# акционные_покупки                                   -0.001828
# средний_просмотр_категорий_за_визит                 -0.039673
# неоплаченные_продукты_штук_квартал                  -0.005893
# ошибка_сервиса                                       0.039707
# страниц_за_визит                                    -0.040131
# минут_текущий_месяц                                 -0.052204
# минут_предыдущий_месяц                              -0.065080
# выручка_препредыдущий_месяц                          0.328247
# выручка_текущий_месяц                                0.837886
# выручка_предыдущий_месяц                             1.000000

# %%
plt.figure(figsize=(15,15));
sns.heatmap(market.corr(), annot=True, fmt=".2f");
plt.show();

# %%
market.phik_matrix()
# Out:
# interval columns not set, guessing: ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'минут_текущий_месяц', 'минут_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 'выручка_предыдущий_месяц']
#                                            id  покупательская_активность  \
# id                                   1.000000                   0.984640
# покупательская_активность            0.984640                   1.000000
# тип_сервиса                          0.119882                   0.132247
# разрешить_сообщать                   0.000000                   0.000000
# маркет_актив_6_мес                   0.468922                   0.546370
# маркет_актив_тек_мес                 0.000000                   0.000000
# длительность                         0.049392                   0.101767
# акционные_покупки                    0.414285                   0.506991
# популярная_категория                 0.170373                   0.298036
# средний_просмотр_категорий_за_визит  0.354031                   0.539221
# неоплаченные_продукты_штук_квартал   0.417626                   0.504845
# ошибка_сервиса                       0.203942                   0.223697
# страниц_за_визит                     0.607982                   0.748769
# минут_текущий_месяц                  0.472584                   0.575662
# минут_предыдущий_месяц               0.564821                   0.685078
# выручка_препредыдущий_месяц          0.419776                   0.495174
# выручка_текущий_месяц                0.171698                   0.195470
# выручка_предыдущий_месяц             0.239152                   0.227280
#
#                                      тип_сервиса  разрешить_сообщать  \
# id                                      0.119882            0.000000
# покупательская_активность               0.132247            0.000000
# тип_сервиса                             1.000000            0.286278
# разрешить_сообщать                      0.286278            1.000000
# маркет_актив_6_мес                      0.094182            0.000000
# маркет_актив_тек_мес                    0.044796            0.051971
# длительность                            0.401158            0.253956
# акционные_покупки                       0.033339            0.017252
# популярная_категория                    0.066285            0.071769
# средний_просмотр_категорий_за_визит     0.186635            0.069322
# неоплаченные_продукты_штук_квартал      0.120842            0.195442
# ошибка_сервиса                          0.076182            0.020464
# страниц_за_визит                        0.100832            0.041128
# минут_текущий_месяц                     0.000000            0.000000
# минут_предыдущий_месяц                  0.131084            0.042350
# выручка_препредыдущий_месяц             0.068507            0.000000
# выручка_текущий_месяц                   0.123698            0.062923
# выручка_предыдущий_месяц                0.000000            0.079830
#
#                                      маркет_актив_6_мес  маркет_актив_тек_мес  \
# id                                             0.468922              0.000000
# покупательская_активность                      0.546370              0.000000
# тип_сервиса                                    0.094182              0.044796
# разрешить_сообщать                             0.000000              0.051971
# маркет_актив_6_мес                             1.000000              0.080454
# маркет_актив_тек_мес                           0.080454              1.000000
# длительность                                   0.000000              0.174385
# акционные_покупки                              0.278729              0.000000
# популярная_категория                           0.149812              0.136175
# средний_просмотр_категорий_за_визит            0.205783              0.246726
# неоплаченные_продукты_штук_квартал             0.286304              0.143827
# ошибка_сервиса                                 0.147270              0.116310
# страниц_за_визит                               0.394108              0.000000
# минут_текущий_месяц                            0.328385              0.062485
# минут_предыдущий_месяц                         0.363780              0.106879
# выручка_препредыдущий_месяц                    0.312243              0.000000
# выручка_текущий_месяц                          0.032055              0.000000
# выручка_предыдущий_месяц                       0.149129              0.054683
#
#                                      длительность  акционные_покупки  \
# id                                       0.049392           0.414285
# покупательская_активность                0.101767           0.506991
# тип_сервиса                              0.401158           0.033339
# разрешить_сообщать                       0.253956           0.017252
# маркет_актив_6_мес                       0.000000           0.278729
# маркет_актив_тек_мес                     0.174385           0.000000
# длительность                             1.000000           0.000000
# акционные_покупки                        0.000000           1.000000
# популярная_категория                     0.000000           0.122840
# средний_просмотр_категорий_за_визит      0.187774           0.199417
# неоплаченные_продукты_штук_квартал       0.191923           0.237583
# ошибка_сервиса                           0.174467           0.000000
# страниц_за_визит                         0.122727           0.310741
# минут_текущий_месяц                      0.100502           0.250014
# минут_предыдущий_месяц                   0.024075           0.262189
# выручка_препредыдущий_месяц              0.114058           0.225681
# выручка_текущий_месяц                    0.147580           0.069613
# выручка_предыдущий_месяц                 0.125303           0.065412
#
#                                      популярная_категория  \
# id                                               0.170373
# покупательская_активность                        0.298036
# тип_сервиса                                      0.066285
# разрешить_сообщать                               0.071769
# маркет_актив_6_мес                               0.149812
# маркет_актив_тек_мес                             0.136175
# длительность                                     0.000000
# акционные_покупки                                0.122840
# популярная_категория                             1.000000
# средний_просмотр_категорий_за_визит              0.225622
# неоплаченные_продукты_штук_квартал               0.248558
# ошибка_сервиса                                   0.000000
# страниц_за_визит                                 0.160623
# минут_текущий_месяц                              0.089923
# минут_предыдущий_месяц                           0.195219
# выручка_препредыдущий_месяц                      0.045814
# выручка_текущий_месяц                            0.237957
# выручка_предыдущий_месяц                         0.250974
#
#                                      средний_просмотр_категорий_за_визит  \
# id                                                              0.354031
# покупательская_активность                                       0.539221
# тип_сервиса                                                     0.186635
# разрешить_сообщать                                              0.069322
# маркет_актив_6_мес                                              0.205783
# маркет_актив_тек_мес                                            0.246726
# длительность                                                    0.187774
# акционные_покупки                                               0.199417
# популярная_категория                                            0.225622
# средний_просмотр_категорий_за_визит                             1.000000
# неоплаченные_продукты_штук_квартал                              0.325688
# ошибка_сервиса                                                  0.069908
# страниц_за_визит                                                0.262610
# минут_текущий_месяц                                             0.182708
# минут_предыдущий_месяц                                          0.159393
# выручка_препредыдущий_месяц                                     0.176770
# выручка_текущий_месяц                                           0.092720
# выручка_предыдущий_месяц                                        0.100332
#
#                                      неоплаченные_продукты_штук_квартал  \
# id                                                             0.417626
# покупательская_активность                                      0.504845
# тип_сервиса                                                    0.120842
# разрешить_сообщать                                             0.195442
# маркет_актив_6_мес                                             0.286304
# маркет_актив_тек_мес                                           0.143827
# длительность                                                   0.191923
# акционные_покупки                                              0.237583
# популярная_категория                                           0.248558
# средний_просмотр_категорий_за_визит                            0.325688
# неоплаченные_продукты_штук_квартал                             1.000000
# ошибка_сервиса                                                 0.033392
# страниц_за_визит                                               0.363879
# минут_текущий_месяц                                            0.232121
# минут_предыдущий_месяц                                         0.255982
# выручка_препредыдущий_месяц                                    0.261530
# выручка_текущий_месяц                                          0.230430
# выручка_предыдущий_месяц                                       0.249471
#
#                                      ошибка_сервиса  страниц_за_визит  \
# id                                         0.203942          0.607982
# покупательская_активность                  0.223697          0.748769
# тип_сервиса                                0.076182          0.100832
# разрешить_сообщать                         0.020464          0.041128
# маркет_актив_6_мес                         0.147270          0.394108
# маркет_актив_тек_мес                       0.116310          0.000000
# длительность                               0.174467          0.122727
# акционные_покупки                          0.000000          0.310741
# популярная_категория                       0.000000          0.160623
# средний_просмотр_категорий_за_визит        0.069908          0.262610
# неоплаченные_продукты_штук_квартал         0.033392          0.363879
# ошибка_сервиса                             1.000000          0.182161
# страниц_за_визит                           0.182161          1.000000
# минут_текущий_месяц                        0.178471          0.382533
# минут_предыдущий_месяц                     0.244071          0.478787
# выручка_препредыдущий_месяц                0.140057          0.339672
# выручка_текущий_месяц                      0.000000          0.139529
# выручка_предыдущий_месяц                   0.000000          0.145680
#
#                                      минут_текущий_месяц  \
# id                                              0.472584
# покупательская_активность                       0.575662
# тип_сервиса                                     0.000000
# разрешить_сообщать                              0.000000
# маркет_актив_6_мес                              0.328385
# маркет_актив_тек_мес                            0.062485
# длительность                                    0.100502
# акционные_покупки                               0.250014
# популярная_категория                            0.089923
# средний_просмотр_категорий_за_визит             0.182708
# неоплаченные_продукты_штук_квартал              0.232121
# ошибка_сервиса                                  0.178471
# страниц_за_визит                                0.382533
# минут_текущий_месяц                             1.000000
# минут_предыдущий_месяц                          0.410490
# выручка_препредыдущий_месяц                     0.342683
# выручка_текущий_месяц                           0.256716
# выручка_предыдущий_месяц                        0.195882
#
#                                      минут_предыдущий_месяц  \
# id                                                 0.564821
# покупательская_активность                          0.685078
# тип_сервиса                                        0.131084
# разрешить_сообщать                                 0.042350
# маркет_актив_6_мес                                 0.363780
# маркет_актив_тек_мес                               0.106879
# длительность                                       0.024075
# акционные_покупки                                  0.262189
# популярная_категория                               0.195219
# средний_просмотр_категорий_за_визит                0.159393
# неоплаченные_продукты_штук_квартал                 0.255982
# ошибка_сервиса                                     0.244071
# страниц_за_визит                                   0.478787
# минут_текущий_месяц                                0.410490
# минут_предыдущий_месяц                             1.000000
# выручка_препредыдущий_месяц                        0.421143
# выручка_текущий_месяц                              0.228783
# выручка_предыдущий_месяц                           0.129355
#
#                                      выручка_препредыдущий_месяц  \
# id                                                      0.419776
# покупательская_активность                               0.495174
# тип_сервиса                                             0.068507
# разрешить_сообщать                                      0.000000
# маркет_актив_6_мес                                      0.312243
# маркет_актив_тек_мес                                    0.000000
# длительность                                            0.114058
# акционные_покупки                                       0.225681
# популярная_категория                                    0.045814
# средний_просмотр_категорий_за_визит                     0.176770
# неоплаченные_продукты_штук_квартал                      0.261530
# ошибка_сервиса                                          0.140057
# страниц_за_визит                                        0.339672
# минут_текущий_месяц                                     0.342683
# минут_предыдущий_месяц                                  0.421143
# выручка_препредыдущий_месяц                             1.000000
# выручка_текущий_месяц                                   0.410596
# выручка_предыдущий_месяц                                0.358036
#
#                                      выручка_текущий_месяц  \
# id                                                0.171698
# покупательская_активность                         0.195470
# тип_сервиса                                       0.123698
# разрешить_сообщать                                0.062923
# маркет_актив_6_мес                                0.032055
# маркет_актив_тек_мес                              0.000000
# длительность                                      0.147580
# акционные_покупки                                 0.069613
# популярная_категория                              0.237957
# средний_просмотр_категорий_за_визит               0.092720
# неоплаченные_продукты_штук_квартал                0.230430
# ошибка_сервиса                                    0.000000
# страниц_за_визит                                  0.139529
# минут_текущий_месяц                               0.256716
# минут_предыдущий_месяц                            0.228783
# выручка_препредыдущий_месяц                       0.410596
# выручка_текущий_месяц                             1.000000
# выручка_предыдущий_месяц                          0.835654
#
#                                      выручка_предыдущий_месяц
# id                                                   0.239152
# покупательская_активность                            0.227280
# тип_сервиса                                          0.000000
# разрешить_сообщать                                   0.079830
# маркет_актив_6_мес                                   0.149129
# маркет_актив_тек_мес                                 0.054683
# длительность                                         0.125303
# акционные_покупки                                    0.065412
# популярная_категория                                 0.250974
# средний_просмотр_категорий_за_визит                  0.100332
# неоплаченные_продукты_штук_квартал                   0.249471
# ошибка_сервиса                                       0.000000
# страниц_за_визит                                     0.145680
# минут_текущий_месяц                                  0.195882
# минут_предыдущий_месяц                               0.129355
# выручка_препредыдущий_месяц                          0.358036
# выручка_текущий_месяц                                0.835654
# выручка_предыдущий_месяц                             1.000000

# %%
plt.figure(figsize=(15,15));
sns.heatmap(market.phik_matrix(), annot=True, fmt='.2f');
plt.show();
# Out:
# interval columns not set, guessing: ['id', 'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность', 'акционные_покупки', 'средний_просмотр_категорий_за_визит', 'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'страниц_за_визит', 'минут_текущий_месяц', 'минут_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц', 'выручка_предыдущий_месяц']

# %% [markdown]
# ### Результаты анализа корреляции данных.
#
# Высокую корреляцию показывают признаки по выручке за предыдущий и текущий месяц. Возможно требуется свести все признаки выручки в один.
#
# Также высокую корреляцию показали покупательская активность и страниц за визит. Необходимо будет изучить взаимовлияние признака с высокой корреляцией на целевой признак. Возможно потребуется принять признак Страниц за визит как целевой.

# %% [markdown]
# Исправим мультиколлинеарность признаков:
# Объединим выручку в один признак "выручка"

# %%
market['выручка'] = market['выручка_препредыдущий_месяц'] + market['выручка_предыдущий_месяц'] + \
                    market['выручка_текущий_месяц']
market = market.drop(columns=['выручка_текущий_месяц', 'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц'])
market.head(5)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    4
# 1    Домашний текстиль                                    5
# 2     Товары для детей                                    5
# 3     Товары для детей                                    3
# 4    Домашний текстиль                                    4
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# 0                                   4               2                 5
# 1                                   2               1                 5
# 2                                   0               6                 4
# 3                                   2               3                 2
# 4                                   1               1                 4
#
#    минут_текущий_месяц  минут_предыдущий_месяц  выручка
# 0                 10.0                    12.0  14659.6
# 1                 13.0                     8.0  15341.9
# 2                 13.0                    11.0  17561.4
# 3                 11.0                     8.0  16274.0
# 4                 10.0                    10.0  15251.0

# %% [markdown]
# ## Шаг 6. Использование пайплайнов
# Примените все изученные модели. Для этого используйте пайплайны.
#
# 6.1 Для подготовки данных создайте пайплайн с использованием ColumnTransformer. Количественные и категориальные данные обработайте в пайплайне раздельно.
#
# 6.2 Создайте пайплайн для поиска лучшей модели из изученных: KNeighborsClassifier(), DecisionTreeClassifier(), LogisticRegression(), SVC().
#
# 6.3 Для каждой модели подберите как минимум один гиперпараметр. Масштабируйте данные как минимум двумя методами.
#
# 6.4 Чтобы выбрать лучшую модель, определитесь с подходящей для моделей метрикой. Аргументируйте свой выбор.

# %%
market = market.set_index('id')

# %%
RANDOM_STATE= 7
TEST_SIZE= 0.25

# %%
X_train, X_test, y_train, y_test = train_test_split(
    market.drop(columns=['покупательская_активность', 'страниц_за_визит']),
    market['покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = market['покупательская_активность'])

X_train.shape, X_test.shape
# Out:
# ((972, 13), (325, 13))

# %%
# создаём списки с названиями признаков
cat_columns = X_train.select_dtypes('object').columns.tolist()
ohe_columns = ['разрешить_сообщать', 'популярная_категория']
ord_columns = ['тип_сервиса']
num_columns = X_train.select_dtypes('number').columns.tolist()

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))
    ]
    )


# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['стандарт', 'премиум'],
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
     ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)


# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)


# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])


param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,5),
        'models__max_features': range(2,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1,5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },

    # словарь для модели SVC()
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
        )],
        'models__C': range(1,5),
        'models__kernel': ['linear', 'rbf', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)
randomized_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)

# проверка работы модели на тестовой выборке
# рассчет прогноза на тестовых данных
y_test_pred = randomized_search.predict_proba(X_test)[:,1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strateg...
#                                                   ['тип_сервиса']),
#                                                  ('num', MinMaxScaler(),
#                                                   ['маркет_актив_6_мес',
#                                                    'маркет_актив_тек_мес',
#                                                    'длительность',
#                                                    'акционные_покупки',
#                                                    'средний_просмотр_категорий_за_визит',
#                                                    'неоплаченные_продукты_штук_квартал',
#                                                    'ошибка_сервиса',
#                                                    'минут_текущий_месяц',
#                                                    'минут_предыдущий_месяц',
#                                                    'выручка'])])),
#                 ('models',
#                  LogisticRegression(C=2, penalty='l1', random_state=7,
#                                     solver='liblinear'))])
# Метрика лучшей модели на тренировочной выборке: 0.9014738738738739
# Метрика ROC-AUC на тестовой выборке: 0.8889423848499438

# %%
preds = randomized_search.predict(X_test)
data = pd.DataFrame(data={'Истина':y_test, 'Предсказания':preds, 'Вероятности':y_test_pred})
data
# Out:
#                  Истина     Предсказания  Вероятности
# id
# 215958  Прежний уровень  Прежний уровень     0.194400
# 215952  Прежний уровень  Прежний уровень     0.139275
# 215870  Прежний уровень  Прежний уровень     0.087755
# 215866  Прежний уровень  Прежний уровень     0.147380
# 215473        Снизилась        Снизилась     0.870645
# ...                 ...              ...          ...
# 216475  Прежний уровень  Прежний уровень     0.094138
# 216365  Прежний уровень  Прежний уровень     0.174304
# 215695        Снизилась  Прежний уровень     0.062954
# 216497  Прежний уровень  Прежний уровень     0.043289
# 215754  Прежний уровень  Прежний уровень     0.422210
#
# [325 rows x 3 columns]

# %% [markdown]
# ## Шаг 7. Анализ важности признаков
#
# 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.
#
# 7.2 Сделайте выводы о значимости признаков:
# - какие признаки мало значимы для модели;
# - какие признаки сильнее всего влияют на целевой признак;
# - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.

# %%
best_model = randomized_search.best_estimator_
print(best_model.named_steps.keys())
# Out:
# dict_keys(['preprocessor', 'models'])

# %%
best_model = randomized_search.best_estimator_
linear_model = best_model.named_steps['models']
preprocessor = best_model.named_steps['preprocessor']

explainer = shap.LinearExplainer(linear_model,preprocessor.transform(X_train), feature_names=preprocessor.get_feature_names_out())

shap_values = explainer(preprocessor.transform(X_test))

# %%
# shap.summary_plot(shap_values, preprocessor.transform(X_test), plot_type="bar", max_display=17)
shap.plots.bar(shap_values, max_display=17)

# %%
# shap.summary_plot(shap_values, preprocessor.transform(X_test), plot_type="beeswarm", max_display=17)
shap.plots.beeswarm(shap_values, max_display=17)

# %%
pd.DataFrame(preprocessor.get_feature_names_out(), columns=['Признаки'])
# Out:
#                                              Признаки
# 0                         ohe__разрешить_сообщать_нет
# 1     ohe__популярная_категория_Косметика и аксесуары
# 2           ohe__популярная_категория_Кухонная посуда
# 3   ohe__популярная_категория_Мелкая бытовая техни...
# 4   ohe__популярная_категория_Техника для красоты ...
# 5          ohe__популярная_категория_Товары для детей
# 6                                    ord__тип_сервиса
# 7                             num__маркет_актив_6_мес
# 8                           num__маркет_актив_тек_мес
# 9                                   num__длительность
# 10                             num__акционные_покупки
# 11           num__средний_просмотр_категорий_за_визит
# 12            num__неоплаченные_продукты_штук_квартал
# 13                                num__ошибка_сервиса
# 14                           num__минут_текущий_месяц
# 15                        num__минут_предыдущий_месяц
# 16                                       num__выручка

# %%
i = 8
print(data.iloc[i])
shap.plots.waterfall(shap_values[i])
# Out:
# Истина          Прежний уровень
# Предсказания          Снизилась
# Вероятности            0.695282
# Name: 216321, dtype: object

# %%
i = 45
print(data.iloc[i])
shap.plots.waterfall(shap_values[i])
# Out:
# Истина                Снизилась
# Предсказания    Прежний уровень
# Вероятности            0.040174
# Name: 215821, dtype: object

# %% [markdown]
# ### Промежуточный вывод
#
# В ходе анализа важности признаков были выявлены признаки, которые сильнее всего влияют на целевой признак:
# - минут активности за предыдущий месяц и текущий
# - акционные покупки
# - средний просмотр категорий за визит
# - маркет актив 6 месяцев
# - неоплаченные товары за квартал
# - популярные категории: бытовая техника, техника для красоты и здоровья и товары для детей
#
# Также выявлены признаки, слабо влияющие на целевой:
# - выручка
# - длительность нахождения на сайте
# - разрешить сообщать
# - ошибка сервиса
# - тип сервиса
# - популярная категория: косметика и аксессуары, кухонная посуда
# - маркет актив текущий месяц
#
# Данные наблюдения показывают значимость каждого признака в привлечении активности на сайт. Если стараться развивать наиболее влияющие признаки, то можно удержать или даже повысить активность на сайте.

# %% [markdown]
# ## Шаг 8. Сегментация покупателей
# 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.
#
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
# - Проведите графическое и аналитическое исследование группы покупателей.
# - Сделайте предложения по работе с сегментом для увеличения покупательской активности.
#
# 8.3 Сделайте выводы о сегментах:
# - какой сегмент вы взяли для дополнительного исследования,
# - какие предложения вы сделали и почему.

# %% [markdown]
# Сегментируем пользователей по популярной категории товаров

# %%
data = data.join(market_file.set_index('id'), how='left').drop(columns=['покупательская_активность'])
data = data.join(money.set_index('id'), how='left')
data
# Out:
#                  Истина     Предсказания  Вероятности тип_сервиса  \
# id
# 215958  Прежний уровень  Прежний уровень     0.194400     премиум
# 215952  Прежний уровень  Прежний уровень     0.139275    стандарт
# 215870  Прежний уровень  Прежний уровень     0.087755    стандарт
# 215866  Прежний уровень  Прежний уровень     0.147380    стандарт
# 215473        Снизилась        Снизилась     0.870645    стандарт
# ...                 ...              ...          ...         ...
# 216475  Прежний уровень  Прежний уровень     0.094138    стандарт
# 216365  Прежний уровень  Прежний уровень     0.174304     премиум
# 215695        Снизилась  Прежний уровень     0.062954    стандарт
# 216497  Прежний уровень  Прежний уровень     0.043289    стандарт
# 215754  Прежний уровень  Прежний уровень     0.422210     премиум
#
#        разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# id
# 215958                 да                 4.0                     5
# 215952                 да                 4.9                     4
# 215870                 да                 5.7                     4
# 215866                 да                 3.3                     4
# 215473                нет                 4.1                     3
# ...                   ...                 ...                   ...
# 216475                 да                 3.5                     3
# 216365                 да                 4.4                     5
# 215695                 да                 4.3                     4
# 216497                 да                 4.1                     4
# 215754                 да                 4.6                     3
#
#         длительность  акционные_покупки                  популярная_категория  \
# id
# 215958           692               0.15                       Кухонная посуда
# 215952           869               0.24  Мелкая бытовая техника и электроника
# 215870           803               0.25                     Домашний текстиль
# 215866           945               0.24                     Домашний текстиль
# 215473           336               0.22                     Домашний текстиль
# ...              ...                ...                                   ...
# 216475           577               0.23        Техника для красоты и здоровья
# 216365           597               0.24                      Товары для детей
# 215695           324               0.14        Техника для красоты и здоровья
# 216497           220               0.16                       Кухонная посуда
# 215754           937               0.14                     Домашний текстиль
#
#         средний_просмотр_категорий_за_визит  \
# id
# 215958                                    3
# 215952                                    3
# 215870                                    5
# 215866                                    3
# 215473                                    2
# ...                                     ...
# 216475                                    3
# 216365                                    3
# 215695                                    2
# 216497                                    5
# 215754                                    5
#
#         неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# id
# 215958                                   2               2                12
# 215952                                   1               4                 8
# 215870                                   4               6                 5
# 215866                                   3               4                13
# 215473                                   7               2                 3
# ...                                    ...             ...               ...
# 216475                                   0               4                11
# 216365                                   5               4                15
# 215695                                   7               4                 4
# 216497                                   3               1                 7
# 215754                                   2               4                14
#
#         прибыль
# id
# 215958     3.91
# 215952     4.40
# 215870     4.20
# 215866     4.18
# 215473     4.69
# ...         ...
# 216475     5.01
# 216365     3.63
# 215695     4.36
# 216497     3.57
# 215754     2.69
#
# [325 rows x 15 columns]

# %%
data = data.iloc[:,[0,1,2,9,14]]
data
# Out:
#                  Истина     Предсказания  Вероятности  \
# id
# 215958  Прежний уровень  Прежний уровень     0.194400
# 215952  Прежний уровень  Прежний уровень     0.139275
# 215870  Прежний уровень  Прежний уровень     0.087755
# 215866  Прежний уровень  Прежний уровень     0.147380
# 215473        Снизилась        Снизилась     0.870645
# ...                 ...              ...          ...
# 216475  Прежний уровень  Прежний уровень     0.094138
# 216365  Прежний уровень  Прежний уровень     0.174304
# 215695        Снизилась  Прежний уровень     0.062954
# 216497  Прежний уровень  Прежний уровень     0.043289
# 215754  Прежний уровень  Прежний уровень     0.422210
#
#                         популярная_категория  прибыль
# id
# 215958                       Кухонная посуда     3.91
# 215952  Мелкая бытовая техника и электроника     4.40
# 215870                     Домашний текстиль     4.20
# 215866                     Домашний текстиль     4.18
# 215473                     Домашний текстиль     4.69
# ...                                      ...      ...
# 216475        Техника для красоты и здоровья     5.01
# 216365                      Товары для детей     3.63
# 215695        Техника для красоты и здоровья     4.36
# 216497                       Кухонная посуда     3.57
# 215754                     Домашний текстиль     2.69
#
# [325 rows x 5 columns]

# %% [markdown]
# Сегментируем пользователей по предсказанным категориям

# %%
data_no_change = data.loc[data['Предсказания'] == 'Прежний уровень'].iloc[:,[1,3,4]]
data_no_change.groupby('популярная_категория').sum().round(2)
# Out:
#                                       прибыль
# популярная_категория
# Домашний текстиль                      165.94
# Косметика и аксесуары                  120.06
# Кухонная посуда                         74.37
# Мелкая бытовая техника и электроника   150.45
# Техника для красоты и здоровья         165.72
# Товары для детей                       220.41

# %%
data_no_change.groupby('популярная_категория').sum().round(2).plot.bar();
plt.title('Прибыльность категорий товаров для покупателей с прежним уровнем активности')
plt.show()

# %%
data_change = data.loc[data['Предсказания'] == 'Снизилась'].iloc[:,[1,3,4]]
data_change.groupby('популярная_категория').sum().round(2)
# Out:
#                                       прибыль
# популярная_категория
# Домашний текстиль                       58.63
# Косметика и аксесуары                   92.81
# Кухонная посуда                         76.14
# Мелкая бытовая техника и электроника    14.91
# Техника для красоты и здоровья          49.55
# Товары для детей                       127.58

# %%
data_change.groupby('популярная_категория').sum().round(2).plot.bar();
plt.title('Прибыльность категорий товаров для покупателей со сниженным уровнем активности')
plt.show()

# %% [markdown]
# ### Промежуточный ввывод
#
# Связывая графики Шепли о значимости признаков и график прибыльности заметно выделяется категория "Мелкая бытовая техника и электроника". Для пользователей со сниженной активностью прибыльность для данной категрии уменьшилась. Совмещая значимость данной категории товара по графику Шепли и прибыльность, можно предположить, что увеличив промоакции по данной категории товаров можно увеличить как активность, так и прибыльность.
#
# Также выделяется категория товаров для детей со стабильно высокой прибыльностью, хоть и меньшей значимостью по графикам Шепли. Поддержание или даже увеличение промоакций в данной категории поддерживает уровень активности и прибыльность магазина.

# %% [markdown]
# ## Шаг 9. Общий вывод
# Сделайте общий вывод:
# - опишите задачу;
# - опишите исходные данные и проведённую предобработку;
# - напишите, что вы сделали для поиска лучшей модели;
# - укажите лучшую модель;
# - добавьте выводы и дополнительные предложения для выбранного сегмента покупателей.

# %% [markdown]
# Задачи данного проекта:
# 1. Разработайте модель, которая предскажет вероятность снижения покупательской активности.
# 2. Выделите сегмент покупателей, проанализируйте его и предложите, как увеличить его покупательскую активность. Используйте данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию вы можете проанализировать больше одного сегмента.
#
# Данные для работы находятся в нескольких таблицах.
#
# В ходе предобработки данные были проверены на дубликаиты и пропуски, были устранены неявные дубликаты в данных, устранены выбросы в данных.
#
# Был проведен корреляционный анализ, в ходе которого была выявлена мультиколлинеарность нескольких признаков. Выручка по месяцам была объединена в один признак по этой причине.
#
# Для поиска лучшей модели был создан пайплайн, включающий подготовку данных (включая: OneHotEncoder, OrdinalEncoder, методы масштабирования количественных данных), и обучение и использование модели МО.
#
# С помощью перебора вариантов Пайплайна с разными гиперпараметрами и разными моделями МО была найдена наилучшая модель: LogisticRegression(C=2, penalty='l1', solver='liblinear') с масштабирование количественных признаков MinMaxScaler.
#
# Метрика лучшей модели на тренировочной выборке: 0.90
#
# Метрика ROC-AUC на тестовой выборке: 0.89

# %% [markdown]
# В ходе анализа важности признаков были выявлены признаки, которые сильнее всего влияют на целевой признак:
# - минут активности за предыдущий месяц и текущий
# - акционные покупки
# - средний просмотр категорий за визит
# - маркет актив 6 месяцев
# - неоплаченные товары за квартал
# - популярные категории: бытовая техника, техника для красоты и здоровья и товары для детей
#
# Также выявлены признаки, слабо влияющие на целевой:
# - выручка
# - длительность нахождения на сайте
# - разрешить сообщать
# - ошибка сервиса
# - тип сервиса
# - популярная категория: косметика и аксессуары, кухонная посуда
# - маркет актив текущий месяц
#
# Данные наблюдения показывают значимость каждого признака в привлечении активности на сайт. Если стараться развивать наиболее влияющие признаки, то можно удержать или даже повысить активность на сайте.

# %% [markdown]
# Для изучения сегментов пользователей была взята Категория товаров
#
# Связывая графики Шепли о значимости признаков и график прибыльности заметно выделяется категория "Мелкая бытовая техника и электроника". Для пользователей со сниженной активностью прибыльность для данной категрии уменьшилась. Совмещая значимость данной категории товара по графику Шепли и прибыльность, можно предположить, что увеличив промоакции по данной категории товаров можно увеличить как активность, так и прибыльность.
#
# Также выделяется категория товаров для детей со стабильно высокой прибыльностью, хоть и меньшей значимостью по графикам Шепли. Поддержание или даже увеличение промоакций в данной категории поддерживает уровень активности и прибыльность магазина.
